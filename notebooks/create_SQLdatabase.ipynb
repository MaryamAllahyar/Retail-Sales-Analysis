# %% [markdown]
# # Retail Sales SQL Database Setup
#
# ## Objective
#
# This notebook imports the cleaned retail sales dataset into a SQLite database so that business questions can be answered using SQL.

# %%
import pandas as pd
import sqlite3
from pathlib import Path

data_path = Path("../data/cleaned/cleaned_retail_sales.csv")

df = pd.read_csv(data_path)

print(df.shape)
df.columns.tolist()
# Out:
# (9994, 31)
# ['row_id',
#  'order_id',
#  'order_date',
#  'ship_date',
#  'ship_mode',
#  'customer_id',
#  'customer_name',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'postal_code',
#  'region',
#  'product_id',
#  'category',
#  'sub_category',
#  'product_name',
#  'sales',
#  'quantity',
#  'discount',
#  'profit',
#  'shipping_days',
#  'discount_percentage',
#  'order_year',
#  'order_month_number',
#  'order_month',
#  'order_quarter',
#  'order_year_month',
#  'profit_margin',
#  'profit_margin_percentage',
#  'profit_status']

# %%
##Create the SQLite database
database_path = Path("../sql/retail_sales.db")

connection = sqlite3.connect(database_path)

print(database_path.resolve())
# Out:
# C:\Users\morte\Retail-Sales-Analysis\sql\retail_sales.db

# %%
##Import the DataFrame into SQLite
df.to_sql(
    "retail_sales",
    connection,
    if_exists="replace",
    index=False
)

connection.commit()
