# %% [markdown]
# # Retail Sales Data Cleaning
#
# ## Project Objective
#
# The purpose of this notebook is to clean and prepare the retail sales dataset for exploratory data analysis, SQL analysis, and dashboard development.
#
# The cleaning process includes:
#
# - inspecting the dataset
# - correcting data types
# - checking missing values
# - removing duplicate records
# - validating numerical values
# - creating useful analytical fields
# - exporting a cleaned dataset

# %%
import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
data_path = Path("../data/raw/Superstore Sales-raw.csv")

df = pd.read_csv(data_path)

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %% [markdown]
# ## Initial Data Inspection
#
# The first step is to inspect several rows of the dataset to understand its structure, column names, and values.

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
print(f"Number of rows: {df.shape[0]:,}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 9,994
# Number of columns: 13

# %%
print(f"Column names: {df.columns.tolist():}")
# Out:
# Column names: ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

df.columns.tolist()
# Out:
# ['ship_mode',
#  'segment',
#  'country',
#  'city',
#  'state',
#  'postal_code',
#  'region',
#  'category',
#  'sub_category',
#  'sales',
#  'quantity',
#  'discount',
#  'profit']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ship_mode     9994 non-null   object
#  1   segment       9994 non-null   object
#  2   country       9994 non-null   object
#  3   city          9994 non-null   object
#  4   state         9994 non-null   object
#  5   postal_code   9994 non-null   int64
#  6   region        9994 non-null   object
#  7   category      9994 non-null   object
#  8   sub_category  9994 non-null   object
#  9   sales         9994 non-null   float64
#  10  quantity      9994 non-null   int64
#  11  discount      9994 non-null   float64
#  12  profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
missing_values = df.isna().sum().sort_values(ascending=False)

missing_values
# Out:
# ship_mode       0
# segment         0
# country         0
# city            0
# state           0
# postal_code     0
# region          0
# category        0
# sub_category    0
# sales           0
# quantity        0
# discount        0
# profit          0
# dtype: int64

# %% [markdown]
# ### Missing Value Assessment
#
# The dataset was checked for missing values. Columns with missing observations were reviewed to determine whether rows should be removed, values should be imputed, or the missing values should remain unchanged.

# %%
duplicate_count = df.duplicated().sum()

print(f"Number of fully duplicated rows: {duplicate_count}")
# Out:
# Number of fully duplicated rows: 17

# %%
df = df.drop_duplicates().copy()

print(f"Rows after removing duplicates: {len(df):,}")
# Out:
# Rows after removing duplicates: 9,977

# %%
df.columns
# Out:
# Index(['ship_mode', 'segment', 'country', 'city', 'state', 'postal_code',
#        'region', 'category', 'sub_category', 'sales', 'quantity', 'discount',
#        'profit'],
#       dtype='object')
