# %% [markdown]
# # Retail Sales Performance Analysis
#
# ## Data Cleaning
#
# **Author:** Maryam Allahyar
#
# ### Objective
#
# This notebook prepares the Superstore dataset for analysis by checking data quality, correcting data types, identifying missing values, validating records, and creating a clean dataset for further analysis.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option("display.max_columns", None)

# %%
data_path = Path("../data/raw/Superstore_Sales.csv")

df = pd.read_csv(data_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 data_path = Path("../data/raw/Superstore_Sales.xlsx")
#       2
# ----> 3 df = pd.read_xlsx(data_path)
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'
